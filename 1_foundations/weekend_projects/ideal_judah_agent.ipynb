# %% [markdown]
# # Project Idea: Ideal Judah Agent
# ## Business Requirements & Goals
# - Build an AI agent that acts as the ideal version of yourself (Judah), providing guidance, motivation, and actionable plans.
# - The agent should accept your personal goals, routines, and preferences, and use them to generate daily/weekly plans, reminders, and suggestions.
# - When asked, the agent should retrieve and summarize your goals, routines, and progress.
# - If you feel down or need motivation, the agent should suggest personalized visualizations, affirmations, and uplifting content.
# - Integrate Retrieval-Augmented Generation (RAG) to pull relevant information from your personal notes, documents, or curated knowledge base to provide context-aware advice and answers.
# - The agent should be able to answer questions about your goals, suggest improvements, and adapt its responses based on your feedback and emotional state.
# - Provide a simple interface (chat, dashboard, or voice) for easy interaction.
# - Ensure privacy and security of your personal data.
# ## Example Use Cases
# - "What are my goals for this week?"
# - "Remind me of my morning routine."
# - "I'm feeling low, can you help?" (Agent responds with affirmations, visualizations, and motivational content)
# - "How am I progressing towards my fitness goal?" (Agent uses RAG to pull from your logs/notes)
# - "Suggest improvements to my daily schedule."
# ## RAG Opportunities
# - Use RAG to fetch and summarize your personal notes, past journal entries, or curated articles for context-aware responses.
# - Enhance affirmations and visualizations by retrieving relevant content from a knowledge base or external sources.
# - Provide tailored advice by combining your data with best practices and expert recommendations.

# %%
# Import required libraries for PDF extraction, text processing, and vector storage
from pypdf import PdfReader  # For reading PDF files
import os  # For file and folder operations
import glob  # For listing PDF files in a folder
from chromadb import Client  # For using ChromaDB as a vector stores
from chromadb.utils import embedding_functions  # For embedding text
import numpy as np  # For numerical operations (if needed)
from typing import List, Dict  # For type hints
import gradio as gr  # For building the UI
import logging  # For logging and debugging
import sys  # For system operations
from openai import OpenAI
from dotenv import load_dotenv  # For loading environment variables

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
# list all the pdf files in the documents directory
pdf_files = glob.glob("documents/*.pdf")
print(f"Found {len(pdf_files)} PDF files in the documents directory.")
# Out:
# Found 6 PDF files in the documents directory.

# %%
# Extract text from a PDF file and extract the text using PyPDF2 and save the text in a dictionary with filename as key and text as value
def extract_text_from_pdf(file_path: str) -> str:
    try:
        reader = PdfReader(file_path)
        text = ""
        for page in reader.pages:
            text += page.extract_text() + "\n"
        return text
    except Exception as e:
        logging.error(f"Error reading {file_path}: {e}")
        return ""

# %%
pdf_texts = {}
for pdf_file in pdf_files:
    text = extract_text_from_pdf(pdf_file)
    if text:
        pdf_texts[os.path.basename(pdf_file)] = text

# %%
print(f"Extracted text from {len(pdf_texts)} PDF files.")
# Out:
# Extracted text from 6 PDF files.

# %%
# Create and configure ChromaDB client
chroma_client = Client()

# %%
# Create and configure ChromaDB client with OpenAI embedding function
openai_ef = embedding_functions.OpenAIEmbeddingFunction(api_key=os.getenv("OPENAI_API_KEY"), model_name="text-embedding-ada-002")
chroma_client = Client()

# %%
# Delete existing judah_documents collection and create a new one with OpenAI embeddings
chroma_client.delete_collection(name="judah_documents")
collection = chroma_client.create_collection(name="judah_documents", embedding_function=openai_ef)
for filename, text in pdf_texts.items():
    collection.add(
        documents=[text],
        ids=[filename],
        metadatas=[{"filename": filename}]
    )
print(f"Re-indexed {len(pdf_texts)} documents in new ChromaDB collection.")
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[21], line 5
#       3 collection = chroma_client.create_collection(name="judah_documents", embedding_function=openai_ef)
#       4 for filename, text in pdf_texts.items():
# ----> 5     collection.add(
#       6         documents=[text],
#       7         ids=[filename],
#       8         metadatas=[{"filename": filename}]
#       9     )
#      10 print(f"Re-indexed {len(pdf_texts)} documents in new ChromaDB collection.")
#
# File ~/projects/agentic-ai-learning/.venv/lib/python3.12/site-packages/chromadb/api/models/Collection.py:84, in Collection.add(self, ids, embeddings, metadatas, documents, images, uris)
#      49 def add(
#      50     self,
#      51     ids: OneOrMany[ID],
#    (...)     61     uris: Optional[OneOrMany[URI]] = None,
#      62 ) -> None:
#      63     """Add embeddings to the data store.
#      64     Args:
#      65         ids: The ids of the embeddings you wish to add
#    (...)     81
#      82     """
# ---> 84     add_request = self._validate_and_prepare_add_request(
#      85         ids=ids,
#      86         embeddings=embeddings,
#      87         metadatas=metadatas,
#      88         documents=documents,
#      89         images=images,
#      90         uris=uris,
#      91     )
#      93     self._client._add(
#      94         collection_id=self.id,
#      95         ids=add_request["ids"],
#    (...)    101         database=self.database,
#     102     )
#
# File ~/projects/agentic-ai-learning/.venv/lib/python3.12/site-packages/chromadb/api/models/CollectionCommon.py:95, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      92 @functools.wraps(func)
#      93 def wrapper(self: Any, *args: Any, **kwargs: Any) -> T:
#      94     try:
# ---> 95         return func(self, *args, **kwargs)
#      96     except Exception as e:
#      97         msg = f"{str(e)} in {name}."
#
# File ~/projects/agentic-ai-learning/.venv/lib/python3.12/site-packages/chromadb/api/models/CollectionCommon.py:225, in CollectionCommon._validate_and_prepare_add_request(self, ids, embeddings, metadatas, documents, images, uris)
#     223 if add_records["embeddings"] is None:
#     224     validate_record_set_for_embedding(record_set=add_records)
# --> 225     add_embeddings = self._embed_record_set(record_set=add_records)
#     226 else:
#     227     add_embeddings = add_records["embeddings"]
#
# File ~/projects/agentic-ai-learning/.venv/lib/python3.12/site-packages/chromadb/api/models/CollectionCommon.py:557, in CollectionCommon._embed_record_set(self, record_set, embeddable_fields, is_query)
#     552             return self._embed(
#     553                 input=self._data_loader(uris=cast(URIs, record_set[field])),  # type: ignore[literal-required]
#     554                 is_query=is_query,
#     555             )
#     556         else:
# --> 557             return self._embed(
#     558                 input=record_set[field],  # type: ignore[literal-required]
#     559                 is_query=is_query,
#     560             )
#     561 raise ValueError(
#     562     "Record does not contain any non-None fields that can be embedded."
#     563     f"Embeddable Fields: {embeddable_fields}"
#     564     f"Record Fields: {record_set}"
#     565 )
#
# File ~/projects/agentic-ai-learning/.venv/lib/python3.12/site-packages/chromadb/api/models/CollectionCommon.py:574, in CollectionCommon._embed(self, input, is_query)
#     572         return self._embedding_function.embed_query(input=input)
#     573     else:
# --> 574         return self._embedding_function(input=input)
#     576 config_ef = self.configuration.get("embedding_function")
#     577 if config_ef is not None:
#
# File ~/projects/agentic-ai-learning/.venv/lib/python3.12/site-packages/chromadb/api/types.py:587, in EmbeddingFunction.__init_subclass__.<locals>.__call__(self, input)
#     586 def __call__(self: EmbeddingFunction[D], input: D) -> Embeddings:
# --> 587     result = call(self, input)
#     588     assert result is not None
#     589     return validate_embeddings(cast(Embeddings, normalize_embeddings(result)))
#
# File ~/projects/agentic-ai-learning/.venv/lib/python3.12/site-packages/chromadb/utils/embedding_functions/openai_embedding_function.py:127, in OpenAIEmbeddingFunction.__call__(self, input)
#     124     embedding_params["dimensions"] = self.dimensions
#     126 # Get embeddings
# --> 127 response = self.client.embeddings.create(**embedding_params)
#     129 # Extract embeddings from response
#     130 return [np.array(data.embedding, dtype=np.float32) for data in response.data]
#
# File ~/projects/agentic-ai-learning/.venv/lib/python3.12/site-packages/openai/resources/embeddings.py:129, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     123             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     124                 base64.b64decode(data), dtype="float32"
#     125             ).tolist()
#     127     return obj
# --> 129 return self._post(
#     130     "/embeddings",
#     131     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     132     options=make_request_options(
#     133         extra_headers=extra_headers,
#     134         extra_query=extra_query,
#     135         extra_body=extra_body,
#     136         timeout=timeout,
#     137         post_parser=parser,
#     138     ),
#     139     cast_to=CreateEmbeddingResponse,
#     140 )
#
# File ~/projects/agentic-ai-learning/.venv/lib/python3.12/site-packages/openai/_base_client.py:1249, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1235 def post(
#    1236     self,
#    1237     path: str,
#    (...)   1244     stream_cls: type[_StreamT] | None = None,
#    1245 ) -> ResponseT | _StreamT:
#    1246     opts = FinalRequestOptions.construct(
#    1247         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1248     )
# -> 1249     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/projects/agentic-ai-learning/.venv/lib/python3.12/site-packages/openai/_base_client.py:1037, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1034             err.response.read()
#    1036         log.debug("Re-raising status error")
# -> 1037         raise self._make_status_error_from_response(err.response) from None
#    1039     break
#    1041 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': "This model's maximum context length is 8192 tokens, however you requested 10541 tokens (10541 in your prompt; 0 for the completion). Please reduce your prompt; or completion length.", 'type': 'invalid_request_error', 'param': None, 'code': None}} in add.

# %%
# Helper function to split text into chunks (approx. 2000 tokens, ~8000 characters)
def split_text(text, max_length=8000):
    return [text[i:i+max_length] for i in range(0, len(text), max_length)]

# Delete existing judah_documents collection and create a new one with OpenAI embeddings
#chroma_client.delete_collection(name="judah_documents")
collection = chroma_client.create_collection(name="judah_documents", embedding_function=openai_ef)

# Add all PDF texts in chunks to ChromaDB
for filename, text in pdf_texts.items():
    chunks = split_text(text)
    for idx, chunk in enumerate(chunks):
        chunk_id = f"{filename}_chunk{idx+1}"
        collection.add(
            documents=[chunk],
            ids=[chunk_id],
            metadatas=[{"filename": filename, "chunk": idx+1}]
        )
print(f"Re-indexed {sum(len(split_text(t)) for t in pdf_texts.values())} chunks in new ChromaDB collection.")
# Out:
# Re-indexed 15 chunks in new ChromaDB collection.

# %%
# Create a ChromaDB collection and add PDF texts as documents
collection = chroma_client.create_collection(name="judah_documents")
for filename, text in pdf_texts.items():
    collection.add(
        documents=[text],
        ids=[filename],
        metadatas=[{"filename": filename}]
    )
print(f"Indexed {len(pdf_texts)} documents in ChromaDB.")
# Out:
# /Users/judahgeorge/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:09<00:00, 9.03MiB/s]
# Indexed 6 documents in ChromaDB.

# %%
# test query
query = "work I did in 1 year"
results = collection.query(query_texts=[query], n_results=3)
for i, (result, meta) in enumerate(zip(results['documents'][0], results['metadatas'][0])):
    print(f"Result {i+1} (File: {meta['filename']}, Chunk: {meta['chunk']}):\n{result}\n")
# Out:
# Result 1 (File: Resume to update.pdf, Chunk: 1):
# These  were  the  work  I  did  in  1  year,  can  you  sum  it  up  into  10  lines  so  that  I  can  update  in  my
# resume
#   Led  Network  Automation  initiatives,  detecting  outages  and  traffic  fluctuations,  reducing  alert
# noise,
#
# and
#
# implementing
#
# Machine
#
# Learning
#
# models
#
# for
#
# improved
#
# efficiency.
#  Played  a  pivotal  role  in  CCP  Migration,  ensuring  seamless  application  connectivity,  fixing
# post-migration
#
# issues,
#
# and
#
# demonstrating
#
# leadership
#
# and
#
# troubleshooting
#
# skills.
#  Managed  Legacy  CM  responsibilities  adeptly,  swiftly  resolving  application  issues,  conducting
# knowledge
#
# sharing
#
# sessions,
#
# and
#
# assisting
#
# in
#
# team
#
# transition
#
# post-migration.
#  Enhanced  IOP  TTS  Deflection,  deploying  solutions  and  adjusting  automations  to  handle  delays
# effectively,
#
# ensuring
#
# incident
#
# resolution
#
# and
#
# reporting
#
# to
#
# stakeholders.
#  Strengthened  Auto  Paging  Email  UI,  implementing  SSO  Authentication  and  SSL  Certificates  for
# heightened
#
# security,
#
# and
#
# developing
#
# multiple
#
# new
#
# routes
#
# for
#
# automation.
#  Spearheaded  Lab  Week  Project  "Clear  Desk,"  demonstrating  innovation  in  building  a  full-stack
# application
#
# and
#
# creating
#
# a
#
# website
#
# for
#
# promoting
#
# the
#
# solution.
#  Engaged  in  mentoring  and  knowledge  sharing,  guiding  colleagues  in  automation  development,
# receiving
#
# and
#
# imparting
#
# knowledge
#
# on
#
# various
#
# technical
#
# domains.
#  Presented  with  opportunities  to  learn  and  apply  diverse  technologies,  from  Go  language  to
# Node.js,
#
# React,
#
# SASS,
#
# and
#
# Electron
#
# JS,
#
# showcasing
#
# adaptability
#
# and
#
# skill
#
# acquisition.
#  Received  positive  feedback  and  recognition  from  team  members,  customers,  and  leadership  for
# contributions
#
# in
#
# problem-solving
#
# and
#
# project
#
# execution.
#  Demonstrated  consistent  commitment  to  continuous  improvement,  ownership,  problem-solving,
# and
#
# learning,
#
# culminating
#
# in
#
# substantial
#
# achievements
#
# and
#
# valuable
#
# contributions
#
# to
#
# the
#
# team
#
# and
#
# organization.
#     Led  the  migration  of  RestartIOPServices  from  .Net  to  Python,  enhancing  code  efficiency,
# resiliency,
#
# and
#
# implementing
#
# Adaptive
#
# Card
#
# for
#
# Microsoft
#
# Teams
#
# messages,
#
# improving
#
# system
#
# reliability
#
# and
#
# performance.
#  Developed  Flask  applications  with  CRUD  operations,  SQLite  databases,  and  JWT-based
# authentication,
#
# showcasing
#
# proficiency
#
# in
#
# Python,
#
# APIs,
#
# and
#
# web
#
# development.
#  Hands-on  experience  in  Docker  for  creating  and  managing  multiple  images,  along  with
# deployment
#
# in
#
# Nginx
#
# servers,
#
# demonstrating
#
# proficiency
#
# in
#
# containerization
#
# and
#
# server
#
# setups.
#  Actively  contributed  to  CCP  Cloud  migration,  enabling  connectivity,  and  understanding  various
# tenants,
#
# zones,
#
# and
#
# VM
#
# configurations,
#
# showcasing
#
# cloud
#
# computing
#
# expertise.
#  Proficient  in  Bash  scripting,  Shell  scripting,  JSON  data  manipulation,  and  working  with  CMDBs,
# showcasing
#
# strong
#
# automation
#
# and
#
# configuration
#
# management
#
# skills.
#  Played  a  key  role  in  legacy  CMS  monitoring,  incident  handling,  and  automated  report
# generation,
#
# demonstrating
#
# proactive
#
# troubleshooting
#
# and
#
# reporting
#
# abilities.
#  Extensive  knowledge  in  monitoring  tools  like  Grafana,  Grafana  alerts  setup,  event  management,
# and
#
# implementing
#
# SOPs,
#
# ensuring
#
# proactive
#
# system
#
# health
#
# checks
#
# and
#
# alerts.
#  Valuable  contributions  to  SSL  Util  2.0  testing,  Sectigo  Screen  Scraper  API  implementation,  and
# handling
#
# SSL
#
# details,
#
# showcasing
#
# meticulous
#
# attention
#
# to
#
# security
#
# protocols.
#
# Engaged  in  network  automation,  Kafka  consumption,  Telemetry  API  exploration,  and  Go
# programming,
#
# demonstrating
#
# aptitude
#
# in
#
# data
#
# streaming
#
# and
#
# programming
#
# languages.
#  Collaborated  on  various  projects,  mentored  colleagues,  provided  KT  sessions,  and  engaged  in
# continuous
#
# learning,
#
# exhibiting
#
# strong
#
# teamwork,
#
# leadership,
#
# and
#
# adaptability
#
# in
#
# diverse
#
# tech
#
# environments.
#   Restart  scripts  -  simple  bash  scripts  for  restarting  apps.   Worked  as  a  Python  Developer,  contributing  to  the  development  and  maintenance  of
# scalable
#
# and
#
# eﬃcient
#
# web
#
# applications
#
# and
#
# standalone
#
# automations.
#   Built  secured  and  robust  microservices  using  Flask  and  Django  using  python   Utilized  Python  for  backend  development,  implementing  RESTful  APIs  using  Flask  and
# integrating
#
# third-party
#
# services
#   Developed  and  maintained  database  schemas,  ensuring  optimal  performance  and  data
# integrity.
#   Moved  applications  to  Kubernetes  environment  as  much  as  possible.   CCP  migration  and  what  all  you  learnt  from  the  migration  as  a  leader.   Assumed  a  DevOps  role,  responsible  for  developing,  testing,  maintenance.  Alerting  and
# deploying
#
# the
#
# applications
#
# in
#
# various
#
# environments,
#
# taking
#
# complete
#
# ownership
#
# of
#
# the
#
# automations
#
# built
#
# by
#
# me.
#   XOC  and  tts  related  applications.    Collaboration  Tools:  Jira,  Conﬂuence  Monitoring  and  Logging:  ELK  Stack,  Prometheus,  Grafana   Update  certiﬁcations:  comptia  sec+    Build  a  Network  Anomaly  detection  tool  which  helped  in  iaster  dentification  of  issues  in
# aggregate
#
# routers
#
# and
#
# Firewall
#
# devices
#
# and
#
# mitigating
#
# them
#
# before
#
# the
#
# application
#
# owners
#
# reported
#
# the
#
# issue.
#
#
#
#
# Result 2 (File: 2024 year end review_office.docx.pdf, Chunk: 2):
# h  learnings  this  year:
# Ansible,  AWS,  Service  Now  (In-progress),  Event  Driven  Architecture  (Kafka  and
# RabbitMQ).
#
#
# I  would  like  to  extend  a  special  thanks  to  Sunil,  Sumathy,  Aparna,  and  the  entire  team
# for
#
# their
#
# unwavering
#
# support
#
# and
#
# collaboration
#
# throughout
#
# this
#
# year.
#
# Their
#
# guidance
#
# and
#
# teamwork
#
# have
#
# been
#
# invaluable
#
# in
#
# achieving
#
# our
#
# goals
#
# and
#
# driving
#
# our
#
# projects
#
# to
#
# success.
#
# Year  end  prep:
# Highlight  your  key  accomplishments  in  order  of  priority  -  use  the  same.
# Mention  HSD  device  lookup  -  did  not  add  in  the  review  comments  but  it  made  HSD  life
# easier.
#
# They
#
# use
#
# it
#
# every
#
# single
#
# day.
#
# Even
#
# last
#
# week
#
# it
#
# was
#
# super
#
# helpful
#
# for
#
# them.
#
# It
#
# was
#
# developed
#
# overnight.
#
#
# s.Challenges  -  how  you  overcame  them  or  what  you  learnt  from  them.
# Improvements  from  last  year  on  collaboration  -  Sumathy’s  comment  and  my  goal  as
# well.
#
# Working
#
# independently
#
# vs
#
# working
#
# with
#
# others.
#
# Appreciate
#
# Sunil,
#
# letting
#
# me
#
# take
#
# ownership
#
# and
#
# trusting
#
# me
#
# to
#
# work
#
# with
#
# multiple
#
# leaders
#
# on
#
# various
#
# project
#
# Time  Management  -  Multiple  projects  side  by  side,  assign  my  things  on  priority  and
# work,
#
# I
#
# do
#
# a
#
# good
#
# job
#
# at
#
# it
#
# but
#
# I
#
# can
#
# do
#
# better.
#
# I
#
# need
#
# to
#
# work
#
# on
#
# balancing
#
# between
#
# things.
#
# Sometimes,
#
# especially
#
# when
#
# we
#
# have
#
# deadlines,
#
# I
#
# set
#
# my
#
# mind
#
# and
#
# I
#
# have
#
# so
#
# much
#
# of
#
# desire
#
# that
#
# I
#
# just
#
# very
#
# late
#
# at
#
# night
#
# and
#
# finish
#
# of
#
# things,
#
# Quiz
#
# Arena
#
# -
#
# We’re
#
# projecting
#
# the
#
# whole
#
# team
#
# with
#
# that
#
# tool.
#
# The
#
# stakes
#
# are
#
# very
#
# high
#
# and
#
# I
#
# just
#
# put
#
# in
#
# so
#
# much
#
# of
#
# work,
#
# I
#
# didn’t
#
# need
#
# anybody
#
# to
#
# motivate
#
# or
#
# push
#
# me
#
#
# Examples  for  feedback  if  you’re  confused.
#
# Feedback  ?
# What  skills  or  behaviour  should  u  focus  to  add  more  value  ?
# Are  there  any  areas  where  the  team  is  looking  for  stronger  support  or  new  initiatives?
# Is  there  anything  I  can  do  differently  to  make  your  job  easier  as  my  manager?
#
# Review:
# Prioritizing  your  work  balancing  out  there.  -  Aparna(I  go  deeper  into  one  project  and
# don’t
#
# balance
#
# the
#
# others.
#
# Best  Hire  in  our  team  in  a  very  long  time,  he  knows  so  many  things  at  this  point  which
# even
#
# I
#
# don’t
#
# think
#
# I
#
# know
#
# -
#
#
# Stellar  work  with  SRE  projects  -  budget  improvement  L1  Virtusa
# Anomaly  detection  as  a  service  could  have  done  better  with  EATS.  People  should  be
# able
#
# to
#
# easily
#
# onboard
#
# and
#
# use.
#
# Neats
#
# Plugin.
#
# Lot  of  potential  with  Equator.  Help  Vasantha.  -  Sunil
# Love  you,  your  work.  Good  feedback  from  Kishore  and  Sudharsan  -  Sunil
# Motivate  Rohan.  -  Sunil
# You’re  a  great  individual  player,  but  you  also  need  to  be  more  transparent  with  the  team
# members
#
# -
#
# Vasantha
#
# He’s  working  independently,  he  needs  to  get  help  from  others  when  needed.  I’m  like  this
# as
#
# well.
#
# I’m
#
# working
#
# on
#
# this.
#
# When
#
# he’s
#
# stuck
#
# on
#
# something,
#
# he
#
# needs
#
# to
#
# reach
#
# out
#
# to
#
# others.
#
# If  we  are  in  need  of  something/anything,  right  after  the  senior  folks,  Deepa  or  Vasantha,
# it’s
#
# you
#
# -
#
# Sunil.
#
# Effective  ratings.
#
#
#
#
#
#
# Result 3 (File: Goals-and-affirmations-and-general.pdf, Chunk: 3):
#  US  or  you’re  going  to  start
# working
#
# in
#
# the
#
# US
#
# -
#
# You
#
# should
#
# be
#
# prepared
#
# in
#
# case
#
# you’re
#
# going
#
# to
#
# work,
#
# making
#
# sure
#
# you
#
# quickly
#
# get
#
# a
#
# job
#
# in
#
# the
#
# US
#    Long  term  -  start  a  side  hustle  Which  will  become  a  mainstream  income  in  the  future  helping  you  to  retire  fast  -  meaning  you
# don’t
#
# have
#
# to
#
# live
#
# from
#
# paycheck
#
# to
#
# paycheck
#
# Right  after  waking  up:   Happiness  is  a  habit.  I  choose  happiness  today  I  choose  success  today  I  choose  right  accent
# today
#
# I
#
# choose
#
# love
#
# and
#
# good
#
# will
#
# for
#
# all
#
# today.
#
# I
#
# choose
#
# peace
#
# today.
#  Peace  harmony  and  poise  govern  mind  at  all  times  My  lord  takes  charge  of  my  life  today  and  everyday.  all  things  work  together  for  good  for  me
# today
#
# this
#
# is
#
# a
#
# new
#
# and
#
# wonderful
#
# day
#
# for
#
# me
#  Give  thanks  for  all  my  blessings  several  times  a  day.  Pray  for  peace  happiness  and  prosperity  of
# all
#
# members
#
# of
#
# your
#
# family
#
# association
#
# all
#
# people
#
# everywhere.
#
# Don't
#
# Dwell
#
# on
#
# your
#
# fear
#
# worry
#
# anger
#
# hate
#
# and
#
# failure,
#
# it
#
# will
#
# make
#
# you
#
# depressed
#
# and
#
# unhappy.
#    Day  and  night:   Marriage:   ‘I  am  now  attracting  a  woman  into  my  experience  who  is  honest,  sincere,  loyal,  kind,  faithful,
# and
#
# prosperous.
#
# She
#
# is
#
# peaceful
#
# and
#
# happy.
#  These  qualities  are  sinking  down  into  my  subconscious  mind  now.  As  I  think  about  these  qualities,  they  become  a  part  of  me.  I  know
# that
#
# there’s
#
# an
#
# irresistible
#
# law
#
# of
#
# attraction.
#
# Surely
#
# I
#
# attract
#
# a
#
# man
#
# or
#
# woman
#
# according
#
# to
#
# my
#
# subconscious
#
# beliefs.
#
# I
#
# attract
#
# that
#
# which
#
# I
#
# feel
#
# as
#
# true
#
# in
#
# my
#
# subconscious
#
# mind.
#
# In
#
# other
#
# words,
#
# I
#
# know
#
# that
#
# according
#
# to
#
# the
#
# law,
#
# I
#
# will
#
# attract
#
# a
#
# man
#
# or
#
# woman
#
# in
#
# accordance
#
# with
#
# my
#
# feelings,
#
# beliefs
#
# according
#
# to
#
# the
#
# impressions
#
# made
#
# on
#
# my
#
# subconscious
#
# mind
#
# regarding
#
# the
#
# type
#
# of
#
# man
#
# or
#
# woman
#
# I
#
# seek.’
#    “I  now  attract  the  right  woman  who  is  in  complete  accord  with  me.  This  is  spiritual  union
# because
#
# it
#
# is
#
# divine
#
# love
#
# functioning
#
# through
#
# the
#
# personality
#
# of
#
# someone
#
# with
#
# whom
#
# I
#
# blend
#
# perfectly.
#
# I
#
# know
#
# I
#
# can
#
# give
#
# this
#
# woman
#
# love,
#
# light,
#
# peace,
#
# and
#
# joy.
#
# I
#
# feel
#
# and
#
# believe
#
# I
#
# can
#
# make
#
# this
#
# woman’s
#
# life
#
# full,
#
# complete
#
# and
#
# wonderful.
#  I  now  decree  that  she  possesses  the  following  qualities  and  attributes  (if  you  wish  any  specific
# quality
#
# you
#
# may
#
# include)
#
# She
#
# is
#
# spiritual,
#
# loyal,
#
# faithful,
#
# and
#
# trustworthy.
#
# She
#
# is
#
# harmonious,
#
# peaceful,
#
# and
#
# happy.
#
# We
#
# are
#
# irresistibly
#
# attracted
#
# to
#
# each
#
# other.
#
# Only
#
# that
#
# which
#
# belongs
#
# to
#
# love,
#
# truth,
#
# and
#
# beauty
#
# can
#
# enter
#
# my
#
# experience.
#
# I
#
# accept
#
# my
#
# ideal
#
# companion
#
# now.”
#   I  accept  and  believe  that  Mom  and  Sarah  are  getting  healed  from  all  the  wounds  and  suffering
# and
#
# pain
#
# that
#
# they
#
# have
#
# gone
#
# through
#
# in
#
# their
#
# life.
#
#
# They  are  in  good  health,  happy,  peaceful  and  prosperous  in  all  their  ways.   Sleep  I  accept  and  believe  that  I’m  feeling  really  calm  and  peaceful  as  I’m  going  to  sleep  now.  I’m
# thankful
#
# for
#
# all
#
# the
#
# wonderful
#
# things
#
# in
#
# my
#
# life.
#
# I
#
# believe
#
# that
#
# I’m
#
# going
#
# to
#
# wake
#
# up
#
# refreshed,
#
# energetic
#
# and
#
# in
#
# a
#
# relaxed
#
# state
#
# of
#
# mind
#   I  would  like  to  wake  up  at  ….     Confidence  is  built  from  what  you  do,  a  positive  mindset  i  rooted  in  what  you  do,  loving
# relationships
#
# are
#
# sustained
#
# from
#
# what
#
# you
#
# do,
#
# purposeful
#
# work
#
# is
#
# cultivated
#
# by
#
# doing
#
# it,
#
# not
#
# thinking
#
# about
#
# why
#
# you
#
# should
#
# (and
#
# believing
#
# that's
#
# the
#
# same
#
# thing).
#    Goals  of  the  year   Be  an  Elite  performer  in  career   -  complete  work  exceptionallly  by  the  deadlines  and  have  satisfaction  in  whatever  you  do.  -  Complete  the  courses  which  you  have  planned  and  have  open  source  projects  in  your
# webpage
#
# to
#
# show
#
# that
#
# you
#
# know
#
# the
#
# stuff
#
# mentioned
#
# your
#
# resume
#  -  Move  to  the  US  by  March  2024  -  Be  a  leader  in  the  workplace,  trust  radar  is  very  important.  Think  subjectively/logically.  -  Be  agressive  in  learning  new  stuff  and  becoming  a  mastery  at  your  skills.  -  Selling  is  an  absolute  important  skill   Become  a  great  communicator   -  become  good  at  story  telling  -  expand  your  vocab  -  complete  the  book  -  practice  2  sessions  weekly  in  home  speaking  specific  topics  (  any)  -  15  mins  -  audio  podcasts  and  start  pronouncing  the  words  -  no  to  monotonous  voice  -  use  the  right
# practices
#    Goals  -  5  years   Values:
# Honesty  Enthusiasm  and  passion,  fire  Intelligent  hard  work.  Perseverance  Consistent   Discipline  Respect   Focus,  concentration,  presence  of  mind,  give  your  100%  always,  quick  thinking,   Deal  change.
# Effective
#
# thoughts=
#
# Effective
#
# action
#    Career  goals  in  5  years  To  have  geographical  freedom,  financial  freedom(high  salary)  with  perfect  work  life  balance.
# When
#
# I
#
# mean
#
# geographical
#
# freedom,
#
# i
#
# should
#
# be
#
# allowed
#
# to
#
# work
#
# from
#
# anywhere.
#  To  be  an  SME  on  multiple  technologies.  Be  an  Elite  performer.  Looking  back,  should  have  been
# consistent
#
# with
#
# improving
#
# myself.
#   Personal  goals:  Spend  good  amount  of  time  with  family,  help  with  decisions  and  enjoy  with  family  and  support
# the
#
# family,
#
# bring
#
# whole
#
# family
#
# to
#
# America
#
# by
#
# this
#
# time.
#   Should  have  a  great  wifey,  it  could  start  as  love  as  well.  Trusting  that  God  will  give  me  the  best
# wife.
#
# Hopefully
#
# a
#
# foreign
#
# wife
#   Have   consistent  and  high  cash  flow  side  business(es),  at  least  .  Hopefully  I  learn  and  take  wise
# risk.
#
# This
#
# should
#
# make
#
# atleast
#
# >
#
# 300k
#
# USD
#
# by
#
# this
#
# time.
#   Have  articulating  skills  and  public  speaking  skills(  sense  of  humour  included)   Surrounded  yourself  with  long  term  friends  who  are  there  to  support  you  and  motivate  you.
# Make
#
# sure
#
# to
#
# socialize
#
# with
#
# them
#
# as
#
# well.
#   Have  a  great  toned  body  and  be  handsome,  looking  very  young  with  lot  of  hair  in  the  head.  Be  a
# model.
#
# Eat
#
# healthy
#
# food.
#
#    Should  have  built  atleast  2  floors  with  multiple  houses  in  the  land.  We  should  be  getting  a
# consistent
#
# income
#
# from
#
# this
#
# investment.
#
#  Buy  atleast      Important:  Do  something.  Do  anything.  But  take  action  immediately.  Taking  the  first  step  is  the  most  difficult
# step.
#
# The
#
# hardest
#
# job,
#
# it’s
#
# said,
#
# is
#
# the
#
# one
#
# on
#
# which
#
# you
#
# never
#
# get
#
# started.
#   Successful  habits  in  any  field  1.  Clarity,  ability  to  be  clear  what  you  want  in  life.  Know  where  it  is  you're  going.  Where  Is  the
# you
#
# want
#
# to
#
# be
#
# and
#
# what
#
# you
#
# want.
#  2.  Be  decisive  -  ability  to  make  hard  (decisions).  Successful  people  make  their  decisions  right.  3.  Have  a  vision  -  Dream  big  dreams.  Where  there  is  no  vision,  people  perish.   4.  Competence  5.  Concentration  6.  Consistentency  7.  The  size  of  vocabulary  will  determine  the  height  of  your  success  8.  Commitment  -  ability  to  enthusiastically,  commit  yourself  to  your  works,  goals.  9.  Courage  -  to  confront  your  fears  10.  Keep  moving  forward,  even  when  seeing  setbacks  11.  Don't  let  anything  stop  you.  12.  Confidence  -  by  doing  certain  things  over  and  over  again  to  become  successful  13.  Learn  from  your  setbacks  14.  Have  a  wide  valuable  network  and  foster  the  relationships  -  You  can’t  fly

# %%
# RAG: Use retrieved chunks as context for OpenAI LLM answer, with improved prompt for Ideal Judah Agent objectives
query = "work I did in 1 year"
results = collection.query(query_texts=[query], n_results=3)
context = "\n---\n".join(results['documents'][0])
prompt = f"""You are the Ideal Judah Agent: an AI designed to help Judah achieve his goals, stay motivated, and provide actionable, personalized advice.\n\nYour objectives:\n- Summarize Judah's achievements, routines, and progress.\n- Offer encouragement and motivation based on his personal context.\n- Suggest improvements and next steps.\n- Ensure privacy and empathy in your responses.\n\nUsing the following context from Judah's personal documents, answer the question: '{query}'\n\nContext:\n{context}\n\nYour response should be clear, supportive, and tailored to Judah's needs.\n\nAnswer:"""
response = openai.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are the Ideal Judah Agent, a helpful, empathetic, and motivating assistant."},
        {"role": "user", "content": prompt}
    ]
 )
print("LLM Answer:\n", response.choices[0].message.content)
# Out:
# LLM Answer:
#  In the past year, you've achieved remarkable milestones in network automation, migration projects, and technology adoption. Your leadership in various initiatives, such as Network Automation, CCP Migration, and IOP TTS Deflection, has showcased your problem-solving skills and technical expertise. Your dedication to continuous improvement and learning has been evident with your diverse technology exploration and application development projects.
#
# Moreover, your proactive troubleshooting approach, teamwork spirit, and mentorship have been valuable contributions to the team and organization. Your positive feedback and recognition from colleagues, customers, and leadership highlight the impact of your problem-solving abilities and project execution.
#
# To enhance your achievements further, consider focusing on sustaining a balance between multiple projects, prioritizing work effectively, and seeking collaboration opportunities. Strive to improve time management skills and seek support from team members when needed. Emphasize transparent communication and collaboration to enhance team dynamics and project outcomes.
#
# As you plan your career goals, aim to become an elite performer, excel in leadership roles, and master your skills with a focus on continuous learning. Additionally, work on your communication skills, storytelling abilities, and expand your vocabulary to effectively convey your expertise. Embrace challenges, cultivate a positive mindset, and maintain consistency in self-improvement to achieve your long-term goals, including geographical freedom, financial stability, and personal fulfillment.
#
# Stay committed to your values of honesty, enthusiasm, perseverance, and respect as you navigate your professional and personal journey. Remember, taking action promptly and consistently is key to realizing your aspirations and building a fulfilling life.
#
# Keep up the great work, Judah! Your dedication, skills, and positive mindset will undoubtedly lead you to even greater successes in the future. If you ever need support or guidance, remember I'm here to assist you along the way.

# %%
def answer_query(user_query, history):
    results = collection.query(query_texts=[user_query], n_results=3)
    context = "\n---\n".join(results['documents'][0])
    prompt = f"""You are the Ideal Judah Agent: an AI designed to help Judah achieve his goals, stay motivated, and provide actionable, personalized advice.

Your objectives:
- Summarize Judah's achievements, routines, and progress.
- Offer encouragement and motivation based on his personal context.
- Suggest improvements and next steps.
- Ensure privacy and empathy in your responses.

Using the following context from Judah's personal documents, answer the question: '{user_query}'

Context:
{context}

Your response should be clear, supportive, and tailored to Judah's needs.

Answer:"""
    response = openai.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are the Ideal Judah Agent, a helpful, empathetic, and motivating assistant."},
            {"role": "user", "content": prompt}
        ]
    )
    return response.choices[0].message.content

# %%
# let's create a chat interface using Gradio
iface = gr.ChatInterface(fn=answer_query, title="Ideal Judah Agent", description="Ask the Ideal Judah Agent anything about your goals, progress, and motivation!")
iface.launch()
# Out:
# /Users/judahgeorge/projects/agentic-ai-learning/.venv/lib/python3.12/site-packages/gradio/chat_interface.py:339: UserWarning: The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   self.chatbot = Chatbot(
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# using the chunking strategy helped to reduce the context size and get more relevant results
# OpenAI embeddings are more effective for this use case compared to the default embeddings
# The difference between the embedding models is that OpenAI embeddings are specifically trained on a wide range of text data and are optimized for capturing semantic meaning, making them more suitable for tasks like document retrieval and question answering in this context.

# %%
## Improvements to be done to the agent:
# 1. Better chunking strategy to avoid breaking sentences.
# 2. More sophisticated prompt engineering for the LLM.
# 3. Add memory to the agent to remember past interactions.
# 4. Add more valuable documents to the corpus for richer context.
# --- IGNORE ---
